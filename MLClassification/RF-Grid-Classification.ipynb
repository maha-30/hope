# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
print(np.__version__)

# Reading the Dataset
dataset = pd.read_csv('Social_Network_Ads.csv')
# Out:
# 2.5.1

# %%
dataset.head(133)
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 128  15722758    Male   30            17000          0
# 129  15792102  Female   26            84000          0
# 130  15675185    Male   31            58000          0
# 131  15801247    Male   33            31000          0
# 132  15725660    Male   30            87000          0
#
# [133 rows x 5 columns]

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0         True
# 1    15810944   35            20000          0         True
# 2    15668575   26            43000          0        False
# 3    15603246   27            57000          0        False
# 4    15804002   19            76000          0         True
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1        False
# 396  15706071   51            23000          1         True
# 397  15654296   50            20000          1        False
# 398  15755018   36            33000          0         True
# 399  15594041   49            36000          1        False
#
# [400 rows x 5 columns]

# %%
indep=dataset[['Age', 'EstimatedSalary','Gender_Male']]
dep=dataset['Purchased']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_= sc.fit_transform(X_train)
X_test_= sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'criterion':['gini','entropy'],
              'max_features': ['sqrt','log2'],
              'n_estimators':[10,100]} 



grid = GridSearchCV(RandomForestClassifier(), param_grid, refit = True, verbose = 3,n_jobs=-1,scoring='f1') 
   
# fitting the model for grid search 
grid.fit(X_train_, y_train)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# GridSearchCV(estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              scoring='f1', verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test_) 
   

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, grid_predictions)



# print classification report 
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)

# %%
print(grid.best_params_)
# Out:
# {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 100}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.422498      0.079727         0.094623        0.017723
# 1       1.816824      0.026308         0.158122        0.014406
# 2       0.194266      0.015443         0.067181        0.012976
# 3       1.913074      0.112858         0.207670        0.060337
# 4       0.211909      0.025106         0.057310        0.011343
# 5       2.002137      0.174157         0.186740        0.032236
# 6       0.197318      0.022179         0.063736        0.008324
# 7       1.825962      0.053504         0.189245        0.019243
#
#   param_criterion param_max_features  param_n_estimators  \
# 0            gini               sqrt                  10
# 1            gini               sqrt                 100
# 2            gini               log2                  10
# 3            gini               log2                 100
# 4         entropy               sqrt                  10
# 5         entropy               sqrt                 100
# 6         entropy               log2                  10
# 7         entropy               log2                 100
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'gini', 'max_features': 'sqrt', ...           0.787879
# 1  {'criterion': 'gini', 'max_features': 'sqrt', ...           0.800000
# 2  {'criterion': 'gini', 'max_features': 'log2', ...           0.666667
# 3  {'criterion': 'gini', 'max_features': 'log2', ...           0.800000
# 4  {'criterion': 'entropy', 'max_features': 'sqrt...           0.727273
# 5  {'criterion': 'entropy', 'max_features': 'sqrt...           0.727273
# 6  {'criterion': 'entropy', 'max_features': 'log2...           0.764706
# 7  {'criterion': 'entropy', 'max_features': 'log2...           0.764706
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.789474           0.809524           0.871795           0.888889
# 1           0.842105           0.809524           0.900000           0.923077
# 2           0.777778           0.780488           0.842105           0.833333
# 3           0.842105           0.809524           0.900000           0.923077
# 4           0.810811           0.809524           0.900000           0.848485
# 5           0.842105           0.809524           0.900000           0.923077
# 6           0.789474           0.780488           0.900000           0.882353
# 7           0.842105           0.809524           0.900000           0.923077
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.829512        0.042543                5
# 1         0.854941        0.048824                1
# 2         0.780074        0.062532                8
# 3         0.854941        0.048824                1
# 4         0.819218        0.056570                7
# 5         0.840396        0.069486                4
# 6         0.823404        0.056179                6
# 7         0.847882        0.057954                3

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 100}: 0.9108102345415777

# %%
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[78  7]
#  [ 5 44]]

# %%
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93        85
#            1       0.86      0.90      0.88        49
#
#     accuracy                           0.91       134
#    macro avg       0.90      0.91      0.90       134
# weighted avg       0.91      0.91      0.91       134

# %%
table_pr=pd.DataFrame()

# %%
print(X_test)
# Out:
#      Age  EstimatedSalary  Gender_Male
# 132   30            87000         True
# 309   38            50000        False
# 341   35            75000         True
# 196   30            79000        False
# 246   35            50000        False
# ..   ...              ...          ...
# 168   29           148000         True
# 150   26            15000        False
# 393   60            42000         True
# 66    24            19000         True
# 240   42           149000         True
#
# [134 rows x 3 columns]

# %%
table_pr['Age']=X_test["Age"]
table_pr['Gender_male']=X_test["Gender_Male"]
table_pr['Estimated_Salary']=X_test["EstimatedSalary"]
table_pr['Actual']=y_test
table_pr['Predicted']=grid_predictions

# %%
table_pr.head(134)
# Out:
#      Age  Gender_male  Estimated_Salary  Actual  Predicted
# 132   30         True             87000       0          0
# 309   38        False             50000       0          0
# 341   35         True             75000       0          0
# 196   30        False             79000       0          0
# 246   35        False             50000       0          0
# ..   ...          ...               ...     ...        ...
# 168   29         True            148000       1          1
# 150   26        False             15000       0          0
# 393   60         True             42000       1          1
# 66    24         True             19000       0          0
# 240   42         True            149000       1          1
#
# [134 rows x 5 columns]

# %%
table_pr.to_csv("cm.csv",index=False)

# %%
dataset.columns
# Out:
# Index(['User ID', 'Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='str')

# %%
X_full = dataset[['Age', 'Gender_Male', 'EstimatedSalary']]

full_predictions = grid.predict(X_full)

dataset['Predicted'] = full_predictions
# Out:
# C:\Users\esmoc\.conda\envs\aiml\Lib\site-packages\sklearn\utils\validation.py:2820: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 30
# BMI: 30
# Children: 1
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
#       2 print("Future_Prediction={}".format(Future_Prediction))
#
# File ~\.conda\envs\aiml\Lib\site-packages\sklearn\model_selection\_search.py:627, in BaseSearchCV.predict(self, X)
#     609 """Call predict on the estimator with the best found parameters.
#     610
#     611 Only available if ``refit=True`` and the underlying estimator supports
#    (...)    624     the best found parameters.
#     625 """
#     626 check_is_fitted(self)
# --> 627 return self._wrap_namespace_error("predict", self.best_estimator_.predict, X)
#
# File ~\.conda\envs\aiml\Lib\site-packages\sklearn\model_selection\_search.py:564, in BaseSearchCV._wrap_namespace_error(self, method_name, call, *args, **kwargs)
#     562 """Call ``call`` and rewrite namespace mismatch errors from inner estimator."""
#     563 try:
# --> 564     return call(*args, **kwargs)
#     565 except ValueError as e:
#     566     if "must use the same namespace" not in str(e):
#
# File ~\.conda\envs\aiml\Lib\site-packages\sklearn\ensemble\_forest.py:903, in ForestClassifier.predict(self, X)
#     882 def predict(self, X):
#     883     """
#     884     Predict class for X.
#     885
#    (...)    901         The predicted classes.
#     902     """
# --> 903     proba = self.predict_proba(X)
#     905     if self.n_outputs_ == 1:
#     906         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File ~\.conda\envs\aiml\Lib\site-packages\sklearn\ensemble\_forest.py:945, in ForestClassifier.predict_proba(self, X)
#     943 check_is_fitted(self)
#     944 # Check data
# --> 945 X = self._validate_X_predict(X)
#     947 # Assign chunk of trees to jobs
#     948 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File ~\.conda\envs\aiml\Lib\site-packages\sklearn\ensemble\_forest.py:615, in BaseForest._validate_X_predict(self, X)
#     612 else:
#     613     ensure_all_finite = True
# --> 615 X = validate_data(
#     616     self,
#     617     X,
#     618     dtype=np.float32,
#     619     accept_sparse="csr",
#     620     reset=False,
#     621     ensure_all_finite=ensure_all_finite,
#     622 )
#     623 if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
#     624     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File ~\.conda\envs\aiml\Lib\site-packages\sklearn\utils\validation.py:3059, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    3056     out = X, y
#    3058 if not no_val_X and check_params.get("ensure_2d", True):
# -> 3059     _check_n_features(_estimator, X, reset=reset)
#    3061 return out
#
# File ~\.conda\envs\aiml\Lib\site-packages\sklearn\utils\validation.py:2923, in _check_n_features(estimator, X, reset)
#    2920     return
#    2922 if n_features != estimator.n_features_in_:
# -> 2923     raise ValueError(
#    2924         f"X has {n_features} features, but {estimator.__class__.__name__} "
#    2925         f"is expecting {estimator.n_features_in_} features as input."
#    2926     )
#
# ValueError: X has 5 features, but RandomForestClassifier is expecting 3 features as input.
