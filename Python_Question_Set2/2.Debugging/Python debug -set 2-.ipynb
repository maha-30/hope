# %%
#1.Find the error in the following Python code:
import math
print(Math.sqrt(16))
case sensitive

# %%
#2.Find the error in the following Python code:
def my_function():
    x += 5
    print(x)

x = 10
my_function()
x value is not passed

# %%
#3.x = 5
if x = 10:
    print("x is 10")
need == for comparison

# %%
#4.
numbers = [5, 3, 8, 2]
print(numbers.sort())
none is printed

# %%
#5.
def square(n):
    n * n

print(square(4))
no return

# %%
#6.
my_tuple = (1, 2, 3)
my_tuple[1] = 5
Tuples are immutable

# %%
#7.
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name))
only name is passed

# %%
#8.
a = [1, 2, 3]
b = [1, 2, 3]
if a is b:
    print("Lists are equal")
will not print

# %%
#9.
for i in range(5, 1):
    print(i)

# %%
#10.
student = {"name": "John", "age": 20}
print(student[name])
error as this is key value
