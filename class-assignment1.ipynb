# %%
from multiFuncLib import multiFunctions

# %%
multiFunctions.Subfields()
# Out:
# Sub-Fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
multiFunctions.OddEven()
# Out:
# Enter a number 5
# 5 is Odd number
# (5, 'is Odd number')

# %%
multiFunctions.Elegible()
# Out:
# Your Gender: Male
# Your Age: 30
# Eligible
# 'Eligible'

# %%
multiFunctions.percentage(98,87,95,95,93)
# Out:
# Subject1= 98
# Subject2= 87
# Subject3= 95
# Subject4= 95
# Subject5= 93
# Total: 468
# Percentage: 93.599999999999994
# (468, 93.6)

# %%
multiFunctions.triangle()
# Out:
# Height: 32
# Breadth: 34
# Area formula: (Height*Breadth)/2
# Area of Traingle: 544.0
# Height1: 2
# Height2: 2
# Breadth: 4
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Traingle: 8
# (544.0, 8)
