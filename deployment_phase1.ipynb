# %%
import pickle

# %%
loaded_model=pickle.load(open("Machine_Learning/ML_Supervise_Regression_Linear.sav","rb"))

# %%
result=loaded_model.predict([[13]])
result
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[3964676.04451028]])

# %%
result=loaded_model.predict([[5]])
result
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[1341475.60456002]])
