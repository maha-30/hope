# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
name=input("Enter your institute name ? :")
# Out:
# Enter your institute name ? : HOPE AI

# %%
name=input("Enter your name: ")
name=input("Enter your age:")
name=input("Enter your school name:")
name=input("Enter your degree:")
# Out:
# Enter your name:  Maharashi M S
# Enter your age: 38
# Enter your school name: SBK
# Enter your degree: BE

# %%
a=43
b=34
add=a+b
print("a=",a)
print("b=",b)
print("add =",add)
# Out:
# a= 43
# b= 34
# add = 77

# %%
a=43
b=34
sub=a-b
print("a=",a)
print("b=",b)
print("Sub =",sub)
# Out:
# a= 43
# b= 34
# Sub = 9

# %%
a=63
b=97
mul=a*b
print("a=",a)
print("b=",b)
print("Mul =",mul)
# Out:
# a= 63
# b= 97
# Mul = 6111

# %%
a=76
b=31
div=a/b
print("a=",a)
print("b=",b)
print("Float Div =",div)
# Out:
# a= 76
# b= 31
# Float Div = 2.4516129032258065

# %%
a=76
b=31
div=a//b
print("a=",a)
print("b=",b)
print("Floor Div =",div)
# Out:
# a= 76
# b= 31
# Floor Div = 2

# %%
a=76
b=31
div=a%b
print("a=",a)
print("b=",b)
print("Modulo =",div)
# Out:
# a= 76
# b= 31
# Floor Div = 14

# %%
a=4
b=4
div=a**b
print("a=",a)
print("b=",b)
print("Power =",div)
# Out:
# a= 4
# b= 4
# Power = 256
